# %% [markdown]
# ## Plot ROC curves and show AUC.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc

# %%
roc_raw = pd.read_csv('roc_raw.csv')
roc_k5 = pd.read_csv('roc_k5.csv')
roc_k5_l2 = pd.read_csv('roc_k5_l2.csv')
roc_k5_t07 = pd.read_csv('roc_k5_t07.csv')
roc_k5_delta15 = pd.read_csv('roc_k5_delta15.csv')

# %%
fpr_raw_knn = [0, roc_raw.kNN[0], 1.0]
tpr_raw_knn = [0, roc_raw.kNN[1], 1.0]

fpr_k5_knn = [0, roc_k5.kNN[0], 1.0]
tpr_k5_knn = [0, roc_k5.kNN[1], 1.0]

fpr_k5_l2_knn = [0, roc_k5_l2.kNN[0], 1.0]
tpr_k5_l2_knn = [0, roc_k5_l2.kNN[1], 1.0]

fpr_k5_t07_knn = [0, roc_k5_t07.kNN[0], 1.0]
tpr_k5_t07_knn = [0, roc_k5_t07.kNN[1], 1.0]

fpr_k5_delta15_knn = [0, roc_k5_delta15.kNN[0], 1.0]
tpr_k5_delta15_knn = [0, roc_k5_delta15.kNN[1], 1.0]

# %%
fpr_raw_rf = [0, roc_raw.RF[0], 1.0]
tpr_raw_rf = [0, roc_raw.RF[1], 1.0]

fpr_k5_rf = [0, roc_k5.RF[0], 1.0]
tpr_k5_rf = [0, roc_k5.RF[1], 1.0]

fpr_k5_l2_rf = [0, roc_k5_l2.RF[0], 1.0]
tpr_k5_l2_rf = [0, roc_k5_l2.RF[1], 1.0]

fpr_k5_t07_rf = [0, roc_k5_t07.RF[0], 1.0]
tpr_k5_t07_rf = [0, roc_k5_t07.RF[1], 1.0]

fpr_k5_delta15_rf = [0, roc_k5_delta15.RF[0], 1.0]
tpr_k5_delta15_rf = [0, roc_k5_delta15.RF[1], 1.0]

# %%
fpr_raw_gb = [0, roc_raw.GB[0], 1.0]
tpr_raw_gb = [0, roc_raw.GB[1], 1.0]

fpr_k5_gb = [0, roc_k5.GB[0], 1.0]
tpr_k5_gb = [0, roc_k5.GB[1], 1.0]

fpr_k5_l2_gb = [0, roc_k5_l2.GB[0], 1.0]
tpr_k5_l2_gb = [0, roc_k5_l2.GB[1], 1.0]

fpr_k5_t07_gb = [0, roc_k5_t07.GB[0], 1.0]
tpr_k5_t07_gb = [0, roc_k5_t07.GB[1], 1.0]

fpr_k5_delta15_gb = [0, roc_k5_delta15.GB[0], 1.0]
tpr_k5_delta15_gb = [0, roc_k5_delta15.GB[1], 1.0]

# %%
fpr_raw_ab = [0, roc_raw.AB[0], 1.0]
tpr_raw_ab = [0, roc_raw.AB[1], 1.0]

fpr_k5_ab = [0, roc_k5.AB[0], 1.0]
tpr_k5_ab = [0, roc_k5.AB[1], 1.0]

fpr_k5_l2_ab = [0, roc_k5_l2.AB[0], 1.0]
tpr_k5_l2_ab = [0, roc_k5_l2.AB[1], 1.0]

fpr_k5_t07_ab = [0, roc_k5_t07.AB[0], 1.0]
tpr_k5_t07_ab = [0, roc_k5_t07.AB[1], 1.0]

fpr_k5_delta15_ab = [0, roc_k5_delta15.AB[0], 1.0]
tpr_k5_delta15_ab = [0, roc_k5_delta15.AB[1], 1.0]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize = (7, 6))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_raw_knn, tpr_raw_knn, 
         label='Raw data (AUC = {:.4f})'.format(auc(fpr_raw_knn, tpr_raw_knn)))
plt.plot(fpr_k5_knn, tpr_k5_knn, 
         label='k=5 (AUC = {:.4f})'.format(auc(fpr_k5_knn, tpr_k5_knn)))
plt.plot(fpr_k5_l2_knn, tpr_k5_l2_knn, 
         label='k=5, $\ell=2$ (AUC = {:.4f})'.format(auc(fpr_k5_l2_knn, tpr_k5_l2_knn)))
plt.plot(fpr_k5_t07_knn, tpr_k5_t07_knn, 
         label='k=5, $t=0.7$ (AUC = {:.4f})'.format(auc(fpr_k5_t07_knn, tpr_k5_t07_knn)))
plt.plot(fpr_k5_delta15_knn, tpr_k5_delta15_knn, 
         label='k=5, $β=1.5$ (AUC = {:.4f})'.format(auc(fpr_k5_delta15_knn, tpr_k5_delta15_knn)))
plt.xlabel('FPR (false positive rate)')
plt.ylabel('TPR (true positive rate)')
plt.title('ROC curves. kNN case.')
plt.legend(loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize = (7, 6))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_raw_rf, tpr_raw_rf, 
         label='Raw data (AUC = {:.4f})'.format(auc(fpr_raw_rf, tpr_raw_rf)))
plt.plot(fpr_k5_rf, tpr_k5_rf, 
         label='k=5 (AUC = {:.4f})'.format(auc(fpr_k5_rf, tpr_k5_rf)))
plt.plot(fpr_k5_l2_rf, tpr_k5_l2_rf, 
         label='k=5, $\ell=2$ (AUC = {:.4f})'.format(auc(fpr_k5_l2_rf, tpr_k5_l2_rf)))
plt.plot(fpr_k5_t07_rf, tpr_k5_t07_rf, 
         label='k=5, $t=0.7$ (AUC = {:.4f})'.format(auc(fpr_k5_t07_rf, tpr_k5_t07_rf)))
plt.plot(fpr_k5_delta15_rf, tpr_k5_delta15_rf, 
         label='k=5, $β=1.5$ (AUC = {:.4f})'.format(auc(fpr_k5_delta15_rf, tpr_k5_delta15_rf)))
plt.xlabel('FPR (false positive rate)')
plt.ylabel('TPR (true positive rate)')
plt.title('ROC curves. RF case.')
plt.legend(loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize = (7, 6))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_raw_gb, tpr_raw_gb, 
         label='Raw data (AUC = {:.4f})'.format(auc(fpr_raw_gb, tpr_raw_gb)))
plt.plot(fpr_k5_gb, tpr_k5_gb, 
         label='k=5 (AUC = {:.4f})'.format(auc(fpr_k5_gb, tpr_k5_gb)))
plt.plot(fpr_k5_l2_gb, tpr_k5_l2_gb, 
         label='k=5, $\ell=2$ (AUC = {:.4f})'.format(auc(fpr_k5_l2_gb, tpr_k5_l2_gb)))
plt.plot(fpr_k5_t07_gb, tpr_k5_t07_gb, 
         label='k=5, $t=0.7$ (AUC = {:.4f})'.format(auc(fpr_k5_t07_gb, tpr_k5_t07_gb)))
plt.plot(fpr_k5_delta15_gb, tpr_k5_delta15_gb, 
         label='k=5, $β=1.5$ (AUC = {:.4f})'.format(auc(fpr_k5_delta15_gb, tpr_k5_delta15_gb)))
plt.xlabel('FPR (false positive rate)')
plt.ylabel('TPR (true positive rate)')
plt.title('ROC curves. GB case.')
plt.legend(loc='best')
plt.show()

# %%
fpr_k5_gb, tpr_k5_gb
# Out:
# ([0, 0.0847058823529411, 1.0], [0, 0.5363283416528009, 1.0])

# %%
fpr_k5_t07_gb, tpr_k5_t07_gb
# Out:
# ([0, 0.087224031849439, 1.0], [0, 0.5389321468298109, 1.0])

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 2, figsize = (13, 13))
axs[0,0].plot([0, 1], [0, 1], 'k--')
axs[0,0].plot(fpr_raw_knn, tpr_raw_knn, color = '#0000FF',
         label='Raw data (AUC = {:.4f})'.format(auc(fpr_raw_knn, tpr_raw_knn)))
axs[0,0].plot(fpr_k5_knn, tpr_k5_knn, color = '#efcf2e',
         label='k=5 (AUC = {:.4f})'.format(auc(fpr_k5_knn, tpr_k5_knn)))
axs[0,0].plot(fpr_k5_l2_knn, tpr_k5_l2_knn, color = '#1ebc14',
         label='k=5, $\ell=2$ (AUC = {:.4f})'.format(auc(fpr_k5_l2_knn, tpr_k5_l2_knn)))
axs[0,0].plot(fpr_k5_t07_knn, tpr_k5_t07_knn, color = '#FF00FF',
         label='k=5, $t=0.7$ (AUC = {:.4f})'.format(auc(fpr_k5_t07_knn, tpr_k5_t07_knn)))
axs[0,0].plot(fpr_k5_delta15_knn, tpr_k5_delta15_knn, color = '#2ee9ef',
         label='k=5, $δ=1.5$ (AUC = {:.4f})'.format(auc(fpr_k5_delta15_knn, tpr_k5_delta15_knn)))
axs[0,0].set_xlabel('False Positive Rate (FPR)', fontsize = 12.5)
axs[0,0].set_ylabel('True Positive Rate (TPR)', fontsize = 12.5)
axs[0,0].set_title('k-Nearest Neighbors', fontsize = 16)

axs[0,1].plot([0, 1], [0, 1], 'k--')
axs[0,1].plot(fpr_raw_rf, tpr_raw_rf, color = '#0000FF',
         label='Raw data (AUC = {:.4f})'.format(auc(fpr_raw_rf, tpr_raw_rf)))
axs[0,1].plot(fpr_k5_rf, tpr_k5_rf, color = '#efcf2e',
         label='k=5 (AUC = {:.4f})'.format(auc(fpr_k5_rf, tpr_k5_rf)))
axs[0,1].plot(fpr_k5_l2_rf, tpr_k5_l2_rf, color = '#1ebc14',
         label='k=5, $\ell=2$ (AUC = {:.4f})'.format(auc(fpr_k5_l2_rf, tpr_k5_l2_rf)))
axs[0,1].plot(fpr_k5_t07_rf, tpr_k5_t07_rf, color = '#FF00FF',
         label='k=5, $t=0.7$ (AUC = {:.4f})'.format(auc(fpr_k5_t07_rf, tpr_k5_t07_rf)))
axs[0,1].plot(fpr_k5_delta15_rf, tpr_k5_delta15_rf, color = '#2ee9ef',
         label='k=5, $δ=1.5$ (AUC = {:.4f})'.format(auc(fpr_k5_delta15_rf, tpr_k5_delta15_rf)))
axs[0,1].set_xlabel('False Positive Rate (FPR)', fontsize = 12.5)
axs[0,1].set_ylabel('True Positive Rate (TPR)', fontsize = 12.5)
axs[0,1].set_title('Random Forest', fontsize = 16)


axs[1,0].plot([0, 1], [0, 1], 'k--')
axs[1,0].plot(fpr_raw_ab, tpr_raw_ab, color = '#0000FF',
         label='Raw data (AUC = {:.4f})'.format(auc(fpr_raw_ab, tpr_raw_ab)))
axs[1,0].plot(fpr_k5_ab, tpr_k5_ab, color = '#efcf2e',
         label='k=5 (AUC = {:.4f})'.format(auc(fpr_k5_ab, tpr_k5_ab)))
axs[1,0].plot(fpr_k5_l2_ab, tpr_k5_l2_ab, color = '#1ebc14',
         label='k=5, $\ell=2$ (AUC = {:.4f})'.format(auc(fpr_k5_l2_ab, tpr_k5_l2_ab)))
axs[1,0].plot(fpr_k5_t07_ab, tpr_k5_t07_ab, color = '#FF00FF',
         label='k=5, $t=0.7$ (AUC = {:.4f})'.format(auc(fpr_k5_t07_ab, tpr_k5_t07_ab)))
axs[1,0].plot(fpr_k5_delta15_ab, tpr_k5_delta15_ab, color = '#2ee9ef',
         label='k=5, $δ=1.5$ (AUC = {:.4f})'.format(auc(fpr_k5_delta15_ab, tpr_k5_delta15_ab)))
axs[1,0].set_xlabel('False Positive Rate (FPR)', fontsize = 12.5)
axs[1,0].set_ylabel('True Positive Rate (TPR)', fontsize = 12.5)
axs[1,0].set_title('Adaptive Boosting', fontsize = 16)

axs[1,1].plot([0, 1], [0, 1], 'k--')
axs[1,1].plot(fpr_raw_gb, tpr_raw_gb, color = '#0000FF',
         label='Raw data (AUC = {:.4f})'.format(auc(fpr_raw_gb, tpr_raw_gb)))
axs[1,1].plot(fpr_k5_gb, tpr_k5_gb, color = '#efcf2e',
         label='k=5 (AUC = {:.4f})'.format(auc(fpr_k5_gb, tpr_k5_gb)))
axs[1,1].plot(fpr_k5_l2_gb, tpr_k5_l2_gb, color = '#1ebc14',
         label='k=5, $\ell=2$ (AUC = {:.4f})'.format(auc(fpr_k5_l2_gb, tpr_k5_l2_gb)))
axs[1,1].plot(fpr_k5_t07_gb, tpr_k5_t07_gb, color = '#FF00FF',
         label='k=5, $t=0.7$ (AUC = {:.4f})'.format(auc(fpr_k5_t07_gb, tpr_k5_t07_gb)))
axs[1,1].plot(fpr_k5_delta15_gb, tpr_k5_delta15_gb, color = '#2ee9ef',
         label='k=5, $δ=1.5$ (AUC = {:.4f})'.format(auc(fpr_k5_delta15_gb, tpr_k5_delta15_gb)))
axs[1,1].set_xlabel('False Positive Rate (FPR)', fontsize = 12.5)
axs[1,1].set_ylabel('True Positive Rate (TPR)', fontsize = 12.5)
axs[1,1].set_title('Gradient Tree Boosting', fontsize = 16)


axs[0,0].legend(loc='best', fontsize = 12)
axs[0,1].legend(loc='best', fontsize = 12)
axs[1,0].legend(loc='best', fontsize = 12)
axs[1,1].legend(loc='best', fontsize = 12)
plt.show()

# %%
fig.savefig('roc_all_models.svg')

# %%
fig.savefig('roc_all_models.png')
